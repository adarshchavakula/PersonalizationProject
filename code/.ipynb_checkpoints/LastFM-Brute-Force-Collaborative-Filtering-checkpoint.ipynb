# %% [markdown]
# # Brute Force Collaborative Filtering

# %% [markdown]
# Notebook to perform brute force collaborative filtering on the LastFM dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from multiprocessing import Pool
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv("~/Columbia/Personalization Theory/lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv", 
                   delimiter="\t", header=None, 
                   names = ["userid","timestamp","musicbrainz-artist-id",
                            "artist-name","musicbrainz-track-id","track-name"])

# %%
print("Total number of rows:", len(data))
data.head(5)
# Out:
# Total number of rows: 19098862
#         userid             timestamp                 musicbrainz-artist-id  \
# 0  user_000001  2009-05-04T23:08:57Z  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1  user_000001  2009-05-04T13:54:10Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  user_000001  2009-05-04T13:52:04Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  user_000001  2009-05-04T13:42:52Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  user_000001  2009-05-04T13:42:11Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#   artist-name musicbrainz-track-id                                  track-name
# 0   Deep Dish                  NaN  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1        坂本龍一                  NaN           Composition 0919 (Live_2009_4_15)
# 2        坂本龍一                  NaN                        Mc2 (Live_2009_4_15)
# 3        坂本龍一                  NaN                     Hibari (Live_2009_4_15)
# 4        坂本龍一                  NaN                        Mc1 (Live_2009_4_15)

# %% [markdown]
# ## Group data into artists and users

# %%
user_artist_groups = data.groupby(['userid','artist-name'])['timestamp'].count().reset_index()
user_artist_groups.columns = ['userid', 'artist-name', 'count']

# %%
user_artist_groups.head(5)
# Out:
#         userid artist-name  count
# 0  user_000001        2562     26
# 1  user_000001         310      1
# 2  user_000001        3582      1
# 3  user_000001     4 Wings      2
# 4  user_000001       4Hero    146

# %%
user_artist_groups.tail(5)
# Out:
#              userid artist-name  count
# 897416  user_001000      Zigmat      1
# 897417  user_001000      Zion I      2
# 897418  user_001000         Zy-      2
# 897419  user_001000       浜崎あゆみ      1
# 897420  user_001000        長沼英樹     18

# %% [markdown]
# ### Save the file!

# %% [markdown]
# Let's save this grouped data into a csv for later use

# %%
user_artist_groups.to_csv("users_and_artists.csv", index=False)

# %%
unique_users = np.unique(user_artist_groups["userid"])
unique_artists = np.unique(user_artist_groups["artist-name"])

# %%
print('Number of unique users:', len(unique_users))
print('Number of unique artists:', len(unique_artists))
# Out:
# Number of unique users: 992
# Number of unique artists: 173923

# %% [markdown]
# ## Making Train-Test splits

# %%
train_data = pd.DataFrame()
test_data = pd.DataFrame()

# %%
user_artist_groups = pd.read_csv("users_and_artists.csv")

# %%
for u in unique_users:
    user_u_all_data = user_artist_groups.loc[user_artist_groups["userid"]==u,:]
    user_u_train, user_u_test = train_test_split(user_u_all_data, test_size=0.20, random_state=42)
    train_data = train_data.append(user_u_train)
    test_data = test_data.append(user_u_test)

# %%
train_data
# Out:
#              userid                                        artist-name  count
# 227     user_000001                                         Hippiehaus      5
# 559     user_000001                                      The Black Dog    149
# 363     user_000001                                        Marvin Gaye      5
# 61      user_000001                                         Billy Joel      1
# 578     user_000001                                          The Verve     46
# 569     user_000001                                       The Lost Men     12
# 29      user_000001                                      Angela Bofill      4
# 265     user_000001            Jazzanova Feat. Pedro Martins & Azymuth     18
# 148     user_000001                                            Dj Rels      2
# 209     user_000001                             Grover Washington, Jr.      1
# 300     user_000001                                              Kayot      3
# 390     user_000001                          Mlle Caro & Franck Garcia      3
# 281     user_000001                                       John Beltran      4
# 335     user_000001                                Lonnie Liston Smith      1
# 445     user_000001                                             Precyz      3
# 299     user_000001                                           Kawabata     17
# 525     user_000001                                     Spencer Bohren     34
# 332     user_000001                                               Loka      1
# 467     user_000001                                          Rip Slyme      1
# 616     user_000001                                              Wiley      1
# 417     user_000001                                       Papo Vazquez      2
# 563     user_000001                             The Detroit Experiment      5
# 544     user_000001                                             Switch     17
# 453     user_000001                                     Raphael Saadiq      3
# 369     user_000001                                     Matthew Burton      1
# 104     user_000001                             Clara Hill'S Folkwaves      8
# 114     user_000001                                    Creative Source      1
# 163     user_000001                                         Eddie Russ      2
# 507     user_000001                                       Silent Poets     24
# 234     user_000001                                              I-Dep      1
# ...             ...                                                ...    ...
# 897221  user_001000                                       Rosie Thomas      1
# 897307  user_001000                                     The Black Keys     86
# 896999  user_001000                                       Jamie Lidell     55
# 896768  user_001000                                         Amy Millan      1
# 897060  user_001000                                            Krs-One      1
# 897206  user_001000             Really Doe Feat. Kanye West & Vince P.      1
# 896907  user_001000                                      Elliott Smith    111
# 897023  user_001000                                       Julie Doiron      1
# 896938  user_001000                                         Gang Starr      1
# 897132  user_001000                                             Mogwai     52
# 897160  user_001000                             Old Crow Medicine Show      1
# 897238  user_001000                     Sharon Jones And The Dap-Kings      3
# 897090  user_001000                                           Lykke Li      1
# 897055  user_001000                               Kistehén Tánczenekar     25
# 896877  user_001000                                Death Cab For Cutie    320
# 896846  user_001000                                         Cibo Matto      1
# 897119  user_001000                                               Mgmt     89
# 896834  user_001000                                          Castanets      1
# 897205  user_001000  Ratatat The Eagles Nirvana The Decemberists Yo...     17
# 897077  user_001000                                        Lobsterdust     15
# 896961  user_001000                                          Hangar 18      1
# 897213  user_001000                                     Riceboy Sleeps      1
# 896868  user_001000                                               Cyne      1
# 897361  user_001000                              Thunderbirds Are Now!    105
# 896767  user_001000                                            Amplive      7
# 896818  user_001000                                            Braille      1
# 896853  user_001000                                            Coldcut      1
# 897017  user_001000                        John Scofield & Pat Metheny      1
# 897182  user_001000                                          Pete Rock      1
# 896849  user_001000                           Clap Your Hands Say Yeah     69
#
# [717545 rows x 3 columns]

# %%
test_data
# Out:
#              userid                                        artist-name  count
# 627     user_000001                                           Yanokami     42
# 271     user_000001                                          Jeff Beck     15
# 290     user_000001                                    Jonny Greenwood      2
# 63      user_000001                                              Björk    448
# 302     user_000001                                          Ken Ishii     13
# 78      user_000001                               Boom Boom Satellites     16
# 644     user_000001                                                 大樹     71
# 576     user_000001                                 The Sugarhill Gang      1
# 72      user_000001                                         Bobby Cole     17
# 221     user_000001                                      Henry Mancini      2
# 506     user_000001                                             Signal      1
# 135     user_000001                                            Des'Ree     21
# 248     user_000001                           Jacob'S Optical Stairway      3
# 511     user_000001                                       Skindo-Le-Le      3
# 310     user_000001                                               Koop      1
# 430     user_000001                                      Pharoah Roche      6
# 292     user_000001                                                Jpl      3
# 328     user_000001                                     Linda Williams      2
# 249     user_000001                                       Jaga Jazzist      1
# 55      user_000001                                        Benny Sings      4
# 247     user_000001                      Jackson And His Computer Band     17
# 109     user_000001                                             Cokiyu     30
# 235     user_000001                                        Ian O'Brien    145
# 350     user_000001                                              Lypid     22
# 344     user_000001                                       Lucky & Easy     53
# 593     user_000001                                           Towa Tei    256
# 101     user_000001                                   Christoffer Berg     15
# 320     user_000001                                         Lark Daddy      1
# 573     user_000001                                      The Rh Factor      3
# 540     user_000001                                             Sun Ra      2
# ...             ...                                                ...    ...
# 896833  user_001000                                        Carl Spidla      1
# 896923  user_001000                                       Flying Lotus     80
# 897114  user_001000                            Medeski Martin And Wood     39
# 897342  user_001000                                       The Pharcyde      2
# 897374  user_001000                                           Tunturia      1
# 897286  user_001000                                             Surkin      1
# 896912  user_001000                              Explosions In The Sky     32
# 896788  user_001000                                       Baden Powell     18
# 897230  user_001000                                          Santogold    108
# 896855  user_001000  Coldplay + Weezer + Cut Copy + The Blow + M.I....     19
# 897298  user_001000                                               Thao    228
# 896803  user_001000                                         Black Dice      1
# 896955  user_001000                                  Groove Collective     24
# 897204  user_001000                                            Ratatat    232
# 897137  user_001000      Mount Eerie With Julie Doiron And Fred Squire      1
# 896883  user_001000                                             Despot      1
# 896974  user_001000                                       Honkeyfinger      1
# 897233  user_001000                                      Scapegoat Wax      1
# 896878  user_001000                              Death From Above 1979    117
# 896771  user_001000                         Andrew Bird'S Bowl Of Fire     56
# 897285  user_001000                                   Super Mash Bros.     61
# 897110  user_001000                                         Matt & Kim      1
# 896957  user_001000                                     Guilty Simpson      1
# 897350  user_001000                                          The Shins    177
# 896857  user_001000                                             Common    242
# 896829  user_001000                                      Calvin Harris      1
# 896798  user_001000                                            Beyoncé      1
# 896951  user_001000                                        Grant Green      1
# 897289  user_001000                                        Talib Kweli      1
# 897172  user_001000                                         Panda Bear     39
#
# [179876 rows x 3 columns]

# %%
train_data.to_csv("train_data.csv", index=False)
test_data.to_csv("test_data.csv", index=False)

# %% [markdown]
# ## Make the matrix

# %%
count_matrix = pd.DataFrame(columns = unique_users, index=unique_artists)

# %%
count_matrix
# Out:
#                                                    user_000001 user_000002  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000003 user_000004  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000005 user_000006  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000007 user_000008  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000009 user_000010  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                        ...     user_000991  \
# ! Europe - France - Cold Wave                          ...             NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain      ...             NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                         ...             NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                        ...             NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                   ...             NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...     ...             NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus             ...             NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                 ...             NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec               ...             NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...     ...             NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                         ...             NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                 ...             NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                      ...             NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                         ...             NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska            ...             NaN
# ! Www.Polskie-Mp3.Tk ! Variete                         ...             NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...     ...             NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...     ...             NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...     ...             NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                           ...             NaN
# !!!                                                    ...             NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)               ...             NaN
# !!! Vs Lfo                                             ...             NaN
# !!!!!!!!!!!!!!!!!Megalos                               ...             NaN
# !..Mos Def & Massive Attack                            ...             NaN
# !..The Roots & Bt                                      ...             NaN
# !4                                                     ...             NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                    ...             NaN
# !5?B5B ..(0E=&Gt;20                                    ...             NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                         ...             NaN
# ...                                                    ...             ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                  ...             NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                      ...             NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                     ...             NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                            ...             NaN
# Ｆｎ                                                     ...             NaN
# Ｇｈｏｓｔ                                                  ...             NaN
# Ｊ　Ｍａｊｉｋ                                                ...             NaN
# Ｊｅｒｏ (ジェロ)                                             ...             NaN
# Ｋｃｅｊ                                                   ...             NaN
# Ｌｉｓａ                                                   ...             NaN
# Ｌｕｌｕ                                                   ...             NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                        ...             NaN
# Ｍａｙ’Ｎ                                                  ...             NaN
# Ｍａｙ’Ｎ，中島愛                                              ...             NaN
# Ｏns                                                    ...             NaN
# Ｏｒｉｇｉｎａｌ                                               ...             NaN
# Ｓａｔａｎ                                                  ...             NaN
# Ｓｃａｎｄａｌ                                                ...             NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                   ...             NaN
# Ｓｍｓのみなさん                                               ...             NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                ...             NaN
# Ｔｗｏ－Ｍｉｘ                                                ...             NaN
# Ｖｅｒｓａｉｌｌｅｓ                                             ...             NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                       ...             NaN
# ～桜雨～                                                   ...             NaN
# ､ﾖｦ~ｳｱｶｧｮV                                             ...             NaN
# ﾅｰｽｺ(Kiss)                                             ...             NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                         ...             NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                              ...             NaN
# ￼                                                      ...             NaN
#
#                                                    user_000992 user_000993  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000994 user_000995  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000996 user_000997  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_000998 user_000999  \
# ! Europe - France - Cold Wave                              NaN         NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN         NaN
# !!!                                                        NaN         NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN         NaN
# !!! Vs Lfo                                                 NaN         NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN         NaN
# !..Mos Def & Massive Attack                                NaN         NaN
# !..The Roots & Bt                                          NaN         NaN
# !4                                                         NaN         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN         NaN
# !5?B5B ..(0E=&Gt;20                                        NaN         NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN         NaN
# ...                                                        ...         ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN         NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN         NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN         NaN
# Ｆｎ                                                         NaN         NaN
# Ｇｈｏｓｔ                                                      NaN         NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN         NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN         NaN
# Ｋｃｅｊ                                                       NaN         NaN
# Ｌｉｓａ                                                       NaN         NaN
# Ｌｕｌｕ                                                       NaN         NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN         NaN
# Ｍａｙ’Ｎ                                                      NaN         NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN         NaN
# Ｏns                                                        NaN         NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN         NaN
# Ｓａｔａｎ                                                      NaN         NaN
# Ｓｃａｎｄａｌ                                                    NaN         NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN         NaN
# Ｓｍｓのみなさん                                                   NaN         NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN         NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN         NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN         NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN         NaN
# ～桜雨～                                                       NaN         NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN         NaN
# ﾅｰｽｺ(Kiss)                                                 NaN         NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN         NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN         NaN
# ￼                                                          NaN         NaN
#
#                                                    user_001000
# ! Europe - France - Cold Wave                              NaN
# ! Germany - Surfbeat From Beyond The Iron Curtain          NaN
# ! Www.Polskie-Mp3.Tk ! Adam Mi                             NaN
# ! Www.Polskie-Mp3.Tk ! Breakout                            NaN
# ! Www.Polskie-Mp3.Tk ! Budka Suflera                       NaN
# ! Www.Polskie-Mp3.Tk ! Jacek Kaczmarski, Gintro...         NaN
# ! Www.Polskie-Mp3.Tk ! Jan Krzysztof Kelus                 NaN
# ! Www.Polskie-Mp3.Tk ! Justyna I Piotr                     NaN
# ! Www.Polskie-Mp3.Tk ! Katarzyna Groniec                   NaN
# ! Www.Polskie-Mp3.Tk ! Lista Przebojow Programu...         NaN
# ! Www.Polskie-Mp3.Tk ! Molesta                             NaN
# ! Www.Polskie-Mp3.Tk ! Robert Janowski                     NaN
# ! Www.Polskie-Mp3.Tk ! Soundtrack                          NaN
# ! Www.Polskie-Mp3.Tk ! Sweet N                             NaN
# ! Www.Polskie-Mp3.Tk ! Swietlicki I Trzaska                NaN
# ! Www.Polskie-Mp3.Tk ! Variete                             NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN
# ! Www.Polskie-Mp3.Tk ! Wideoteka Doroslego Czlo...         NaN
# ! Www.Polskie-Mp3.Tk ! Zbeer                               NaN
# !!!                                                        NaN
# !!! & Out Hud (Musikdesire.Blogspot.Com)                   NaN
# !!! Vs Lfo                                                 NaN
# !!!!!!!!!!!!!!!!!Megalos                                   NaN
# !..Mos Def & Massive Attack                                NaN
# !..The Roots & Bt                                          NaN
# !4                                                         NaN
# !5:B5B @&Lt;O=A:&Gt;3&Gt; @048&Gt;                        NaN
# !5?B5B ..(0E=&Gt;20                                        NaN
# !;04:&Gt;56:0, "@C&Lt;0=, 654                             NaN
# ...                                                        ...
# Ｃｈｅｍｉｓｔｒｙ/Crystal Kay                                      NaN
# Ｃｈｅｍｉｓｔｒｙ/Gaku-Mc                                          NaN
# Ｃｈｒｉｓ＆Ｎｉｎａ＋Ｆｒｉｅｎｄｓ                                         NaN
# Ｄｊ　Ｋａｗａｓａｋｉ                                                NaN
# Ｆｎ                                                         NaN
# Ｇｈｏｓｔ                                                      NaN
# Ｊ　Ｍａｊｉｋ                                                    NaN
# Ｊｅｒｏ (ジェロ)                                                 NaN
# Ｋｃｅｊ                                                       NaN
# Ｌｉｓａ                                                       NaN
# Ｌｕｌｕ                                                       NaN
# Ｍａｓａ　Ｃｏｌｌｅｃｔｉｖｅ                                            NaN
# Ｍａｙ’Ｎ                                                      NaN
# Ｍａｙ’Ｎ，中島愛                                                  NaN
# Ｏns                                                        NaN
# Ｏｒｉｇｉｎａｌ                                                   NaN
# Ｓａｔａｎ                                                      NaN
# Ｓｃａｎｄａｌ                                                    NaN
# Ｓｈａｂａｚｚ　Ｔｈｅ　Ｄｉｓｃｉｐｌｅ                                       NaN
# Ｓｍｓのみなさん                                                   NaN
# Ｔ．Ｔ．Ｆ．Ｌ                                                    NaN
# Ｔｗｏ－Ｍｉｘ                                                    NaN
# Ｖｅｒｓａｉｌｌｅｓ                                                 NaN
# Ｙｏｕｒ　Ｓｏｎｇ　Ｉｓ　Ｇｏｏｄ，Ｂｅａｔ　Ｃｒｕｓａｄｅｒｓ                           NaN
# ～桜雨～                                                       NaN
# ､ﾖｦ~ｳｱｶｧｮV                                                 NaN
# ﾅｰｽｺ(Kiss)                                                 NaN
# ﾅｰｽｺ(Kiss) 1ﾁ                                             NaN
# ﾔﾵﾁﾸ￐￐￐￐￐                                                  NaN
# ￼                                                          NaN
#
# [173923 rows x 992 columns]

# %% [markdown]
# ### Fill up the values of the matrix

# %%
for index, row in user_artist_groups.iterrows():
    count_matrix.loc[row['artist-name'], row['userid']] = row['count']

# user_000980    -0.062553    -0.076203     0.278656    -0.056015     0.183396
# user_000981    -0.174075    -0.135396     0.960341    -0.169252     0.547459
# user_000982          NaN    -0.233517          NaN          NaN    -0.137003
# user_000983     0.061714    -0.094981     0.007050     0.161929     0.269489
# user_000984     0.299149     0.615348    -0.309721     0.297205     0.007453
# user_000985    -0.247698     0.080552    -1.000000    -0.266320    -0.164212
# user_000986     0.238405     0.035991    -0.068320    -0.041600     0.272147
# user_000987    -0.008481    -0.032176     0.291786    -0.070886    -0.123253
# user_000989     0.104497     0.054869    -0.103515     0.118529     0.053758
# user_000990    -0.044434     0.048810    -0.167125     0.130319     0.044403
# user_000991    -0.009521     0.004849     0.219976     0.064347     0.170332
# user_000992     0.028886    -0.074216    -0.204358    -0.095914     0.146488
# user_000993     0.003574     0.150597     0.188772     0.206980     0.450265
# user_000994     0.006352    -0.037040    -0.246923    -0.039242     0.160422
# user_000995     1.000000     0.123286     0.208624     0.063672    -0.031254
# user_000996     0.123286     1.000000    -0.503173     0.922163    -0.031353
# user_000997     0.208624    -0.503173     1.000000    -0.008105    -0.285736
# user_000998     0.063672     0.922163    -0.008105     1.000000     0.230323
# user_000999    -0.031254    -0.031353    -0.285736     0.230323     1.000000
# user_001000    -0.055747     0.725226     0.454773     0.387675    -0.053248
#
#              user_001000
# user_000001     0.341907
# user_000002     0.179434
# user_000003     0.081204
# user_000004     0.224270
# user_000005    -0.118620
# user_000006     0.597567
# user_000007    -0.087480
# user_000008    -0.069525
# user_000009     0.542334
# user_000010    -0.274807
# user_000011    -0.179957
# user_000012     0.045596
# user_000013     0.062356
# user_000014    -0.133736
# user_000015     0.060939
# user_000016     0.038544
# user_000017     0.216375
# user_000018     0.812148
# user_000019    -0.067631
# user_000020     0.039106
# user_000021    -0.153951
# user_000022     0.019143
# user_000023    -0.160751
# user_000024     0.405033
# user_000025     0.006578
# user_000026     0.164556
# user_000027    -0.180971
# user_000028     0.213662
# user_000029     0.190252
# user_000030     0.407353
# ...                  ...
# user_000970     0.342303
# user_000971     0.405128
# user_000972    -0.171520
# user_000973    -0.130510
# user_000974     0.171751
# user_000975     0.099491
# user_000976    -0.301133
# user_000977     0.040228
# user_000978     0.237965
# user_000979    -0.085982
# user_000980     0.039012
# user_000981     0.882036
# user_000982    -0.194903
# user_000983     0.311274
# user_000984     0.270094
# user_000985    -0.433563
# user_000986    -0.131874
# user_000987    -0.039274
# user_000989     0.107523
# user_000990     0.109546
# user_000991     0.043254
# user_000992     0.005126
# user_000993     0.191038
# user_000994    -0.165205
# user_000995    -0.055747
# user_000996     0.725226
# user_000997     0.454773
# user_000998     0.387675
# user_000999    -0.053248
# user_001000     1.000000
#
# [992 rows x 992 columns]

# %%
N_users
# Out:
# 10

# %%
users
# Out:
# ['user_000001',
#  'user_000002',
#  'user_000003',
#  'user_000004',
#  'user_000005',
#  'user_000006',
#  'user_000007',
#  'user_000008',
#  'user_000009',
#  'user_000010']
